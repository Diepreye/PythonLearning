# %%
#BlackJack
import random
logo = """
.------.            _     _            _    _            _    
|A_  _ |.          | |   | |          | |  (_)          | |   
|( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
| \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
|  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   < 
`-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\\
      |  \/ K|                            _/ |                
      `------'                           |__/           
"""
                   
cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
computer_cards = []
player_cards = []
def random_cards():
    computer_cards.append(random.choice(cards))
    player_cards.append(random.choice(cards))
    print(f"[{computer_cards[0]}]")
    print(player_cards)
    print(f"The sum of your cards is: {sum(player_cards)}")

    

play = input("Do you want to play BlackJack? Type 'y' for yes and 'n' and for no: ")
if play == "y":
    while sum_p < 21:
        print(logo)
        for i in range(2):
            random_cards()
        
        if input("Do you want another card? Type 'y' for yes and 'n' and for no: ") == 'y':
            random_cards()
        print(player_cards)
        print(f"The sum of your cards is: {sum(player_cards)}")
    if sum_p == 21 :
        print("BlackJack")
        if sum_c == 21 :
            print("You lose")
        else:
            print("You win")
    elif sum_p > 21:
        print("you lose")
    elif sum_p < 21 and sum_p > sum_c:
        print("you win")
    else:
        print("you lose")
# Out:
# Do you want to play BlackJack? Type 'y' for yes and 'n' and for no: y
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c93c91467aa8> in <module>
#      26 play = input("Do you want to play BlackJack? Type 'y' for yes and 'n' and for no: ")
#      27 if play == "y":
# ---> 28     while sum_p < 21:
#      29         print(logo)
#      30         for i in range(2):
#
# NameError: name 'sum_p' is not defined

# %%
import random
from IPython.display import clear_output
logo = """
.------.            _     _            _    _            _    
|A_  _ |.          | |   | |          | |  (_)          | |   
|( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
| \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
|  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   < 
`-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\\
      |  \/ K|                            _/ |                
      `------'                           |__/           
"""
       

def play_game():
  print(logo)
  def deal_card():
    """returns a random card from the deck"""
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    card = random.choice(cards)
    return card
  def calculate_score(cards):
    """Take a list of cards and calculate the sum of the cards"""
    if sum(cards) == 21 and len(cards) == 2:
      return 0
    
    if 11 in cards and sum(cards) > 21:
      cards.remove(11)
      cards.append(1)
    return sum(cards)

  def compare_scores(user_score,computer_score):
    if user_score == computer_score:
      return "Draw"
    elif computer_score == 0:
      return "You lose, dealer has a Blackjack"
    elif user_score == 0: 
      return "You win with BlackJack"
    elif user_score > 21:
      return "You lose. You went over 21"
    elif computer_score > 21:
      return "You win. Opponent went over 21"
    elif user_score > computer_score:
      return "You win"
    else:
      return "You lose"
  user_cards = []
  computer_cards = []
  game_over = False
  for i in range(2):
    user_cards.append(deal_card())
    computer_cards.append(deal_card())
  while not game_over:
    user_score = calculate_score(user_cards)
    computer_score = calculate_score(computer_cards)
    print(f" Your cards: {user_cards}, current score: {user_score}")
    print(f" Computer's first card: {computer_cards[0]}")
    if user_score == 0 or user_score > 21 or computer_score == 0:
      game_over = True
    else:
      user_should_deal = input("Type 'y' to get another card, type 'n' to pass")
      if user_should_deal == "y":
        user_cards.append(deal_card())
      else:
        game_over = True

  while computer_score != 0 and computer_score < 17:
    computer_cards.append(deal_card())
    computer_score = calculate_score(computer_cards)
  print(f" Your final hand: {user_cards} and final score: {user_score}")
  print(f" Computer's final hand: {computer_cards}and final score: {computer_score}")
  print(compare_scores(user_score,computer_score))

clear_output()
while input(" Do you want to play a game of Blackjack? Type 'y' or 'no'") == 'y':
  play_game()
